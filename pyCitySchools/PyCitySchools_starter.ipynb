# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_file = "Resources/schools_complete.csv"
student_file = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_file)
school_data_df=pd.DataFrame(school_data)

student_data = pd.read_csv(student_file)
student_data_df=pd.DataFrame(student_data)

# Combine the data into a single dataset.  
school_data_combined_df = pd.merge(student_data_df, school_data_df, how="left", on=["school_name"])
school_data_combined_df.head()
# Out:
#    Student ID     student_name gender  year        school_name  reading_score  \
# 0           0     Paul Bradley      M     9  Huang High School             96
# 1           1     Victor Smith      M    12  Huang High School             90
# 2           2  Kevin Rodriguez      M    12  Huang High School             41
# 3           3    Richard Scott      M    12  Huang High School             89
# 4           4       Bonnie Ray      F     9  Huang High School             87
#
#    maths_score  School ID        type  size   budget
# 0           94          0  Government  2917  1910635
# 1           43          0  Government  2917  1910635
# 2           76          0  Government  2917  1910635
# 3           86          0  Government  2917  1910635
# 4           69          0  Government  2917  1910635

# %% [markdown]
# ## Local Government Area Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average maths score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing maths score (50 or greater)
#
# * Calculate the percentage of students with a passing reading score (50 or greater)
#
# * Calculate the percentage of students who passed maths **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Calculate the total number of schools
total_schools=school_data_df["school_name"].count()

# Calculate the total number of students
total_students=student_data_df["student_name"].count()

# Calculate the total budget
total_budget=school_data_df["budget"].sum()

# Calculate the average maths score
average_maths_score=student_data_df["maths_score"].mean()

# Calculate the average reading score
average_reading_score=student_data_df["reading_score"].mean()

# Calculate the percentage of students with a passing maths score (50 or greater)
passing_maths=student_data_df.loc[student_data_df["maths_score"]>=50]
pass_percentage_maths=(passing_maths["maths_score"].count()/total_students)*100

# Calculate the percentage of students with a passing reading score (50 or greater)
passing_reading=student_data_df.loc[student_data_df["reading_score"]>=50]
pass_percentage_reading=(passing_reading["reading_score"].count()/total_students)*100

# Calculate the percentage of students who passed maths and reading (% Overall Passing)
total_passing_percentage=(school_data_combined_df[(school_data_combined_df["maths_score"]>=50)&(school_data_combined_df["reading_score"]>=50)]["Student ID"].count()/total_students)*100
total_passing_percentage


# Create a dataframe to hold the above results
local_government_area_summary=pd.DataFrame({"Total Schools":[total_schools],"Total Students":[total_students],"Total Budget":[total_budget],"Average Maths Score":[average_maths_score],"Average Reading Score":[average_reading_score],"Maths Passing Percentage":[pass_percentage_maths],"Reading Passing Percentage":[pass_percentage_reading],"Total Pass Percentage":[total_passing_percentage]})
local_government_area_summary.head()
# Optional: give the displayed data cleaner formatting
# Out:
#    Total Schools  Total Students  Total Budget  Average Maths Score  \
# 0             15           39170      24649428            70.338192
#
#    Average Reading Score  Maths Passing Percentage  \
# 0              69.980138                 86.078632
#
#    Reading Passing Percentage  Total Pass Percentage
# 0                   84.426857              72.808272

# %%
total_students
# Out:
# 39170

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarises key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed maths **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# Create an overview table that summarises key metrics about each school, including:

# School Name
# School Type
school_name_type=school_data_combined_df.groupby(["school_name","type"])
school_name_type_df=pd.DataFrame(school_name_type)
# Total Students
total_students_in_school=school_name_type["Student ID"].count()
total_students_in_school

# Total School Budget
school_budget=school_name_type["budget"].mean()
school_budget

# Per Student Budget
per_student_budget=school_budget/total_students_in_school
per_student_budget

# Average Maths Score
average_maths_score_per_school=school_name_type["maths_score"].mean()
average_maths_score_per_school

# Average Reading Score
average_reading_score_per_school=school_name_type["reading_score"].mean()
average_reading_score_per_school

# % Passing Maths
passing_maths_per_school=school_data_combined_df[(school_data_combined_df["maths_score"]>=50)]
passing_maths_percentage_per_school=passing_maths_per_school.groupby(["school_name"]).count()["student_name"]/total_students_in_school*100
passing_maths_percentage_per_school

# % Passing Reading
passing_reading_per_school=school_data_combined_df[(school_data_combined_df["reading_score"]>=50)]
passing_reading_percentage_per_school=passing_reading_per_school.groupby(["school_name"]).count()["student_name"]/total_students_in_school*100
passing_reading_percentage_per_school

# % Overall Passing (The percentage of students that passed maths and reading.)
passing_reading_and_maths_percentage=(school_data_combined_df[(school_data_combined_df["reading_score"]>=50)&(school_data_combined_df["maths_score"]>=50)].groupby("school_name")["Student ID"].count()/total_students_in_school)*100
passing_reading_and_maths_percentage

# Create a dataframe to hold the above results
school_summary=pd.DataFrame({"School Type":school_name_type_df,"Total Students":total_students_in_school,"Total School Budget":school_budget,"Per Student Budget":per_student_budget,"Average Maths Score":average_maths_score_per_school,"Average Reading Score":average_reading_score_per_school,"% Passing Maths":passing_maths_percentage_per_school,"% Passing Reading":passing_reading_percentage_per_school,"% Overall Passing":passing_reading_and_maths_percentage})
school_summary
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 42>()
#      39 passing_reading_and_maths_percentage
#      41 # Create a dataframe to hold the above results
# ---> 42 school_summary=pd.DataFrame({"School Type":school_name_type_df,"Total Students":total_students_in_school,"Total School Budget":school_budget,"Per Student Budget":per_student_budget,"Average Maths Score":average_maths_score_per_school,"Average Reading Score":average_reading_score_per_school,"% Passing Maths":passing_maths_percentage_per_school,"% Passing Reading":passing_reading_percentage_per_school,"% Overall Passing":passing_reading_and_maths_percentage})
#      43 school_summary
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
#     638     import numpy.ma.mrecords as mrecords
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:502, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     494     arrays = [
#     495         x
#     496         if not hasattr(x, "dtype") or not isinstance(x.dtype, ExtensionDtype)
#     497         else x.copy()
#     498         for x in arrays
#     499     ]
#     500     # TODO: can we get rid of the dt64tz special case above?
# --> 502 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:125, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     122         index = ensure_index(index)
#     124     # don't force copy because getting jammed in an ndarray anyway
# --> 125     arrays = _homogenize(arrays, index, dtype)
#     126     # _homogenize ensures
#     127     #  - all(len(x) == len(index) for x in arrays)
#     128     #  - all(x.ndim == 1 for x in arrays)
#    (...)
#     131
#     132 else:
#     133     index = ensure_index(index)
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\construction.py:625, in _homogenize(data, index, dtype)
#     622             val = dict(val)
#     623         val = lib.fast_multiget(val, oindex._values, default=np.nan)
# --> 625     val = sanitize_array(
#     626         val, index, dtype=dtype, copy=False, raise_cast_failure=False
#     627     )
#     628     com.require_length_match(val, index)
#     630 homogenized.append(val)
#
# File ~\anaconda3\lib\site-packages\pandas\core\construction.py:593, in sanitize_array(data, index, dtype, copy, raise_cast_failure, allow_2d)
#     591     subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#     592 else:
# --> 593     subarr = maybe_convert_platform(data)
#     594     if subarr.dtype == object:
#     595         subarr = cast(np.ndarray, subarr)
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py:130, in maybe_convert_platform(values)
#     128 if arr.dtype == _dtype_obj:
#     129     arr = cast(np.ndarray, arr)
# --> 130     arr = lib.maybe_convert_objects(arr)
#     132 return arr
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\lib.pyx:2395, in pandas._libs.lib.maybe_convert_objects()
#
# ValueError: Buffer has wrong number of dimensions (expected 1, got 2)

# %%
passing_maths_percentage_per_school
# Out:
# school_name            type
# Bailey High School     Government     91.639871
# Cabrera High School    Independent    90.850377
# Figueroa High School   Government     81.654798
# Ford High School       Government     82.438846
# Griffin High School    Independent    91.212534
# Hernandez High School  Government     80.949299
# Holden High School     Independent    89.929742
# Huang High School      Government     81.693521
# Johnson High School    Government     82.062592
# Pena High School       Independent    91.683992
# Rodriguez High School  Government     90.797699
# Shelton High School    Independent    91.538898
# Thomas High School     Independent    83.853211
# Wilson High School     Independent    82.785808
# Wright High School     Independent    91.777778
# dtype: float64

# %%
result = pd.concat([school_name_type_df, total_students_in_school], axis=1)
result
# Out:
#                                                                        0  \
# 0                                       (Bailey High School, Government)
# 1                                     (Cabrera High School, Independent)
# 2                                     (Figueroa High School, Government)
# 3                                         (Ford High School, Government)
# 4                                     (Griffin High School, Independent)
# 5                                    (Hernandez High School, Government)
# 6                                      (Holden High School, Independent)
# 7                                        (Huang High School, Government)
# 8                                      (Johnson High School, Government)
# 9                                        (Pena High School, Independent)
# 10                                   (Rodriguez High School, Government)
# 11                                    (Shelton High School, Independent)
# 12                                     (Thomas High School, Independent)
# 13                                     (Wilson High School, Independent)
# 14                                     (Wright High School, Independent)
# (Bailey High School, Government)                                     NaN
# (Cabrera High School, Independent)                                   NaN
# (Figueroa High School, Government)                                   NaN
# (Ford High School, Government)                                       NaN
# (Griffin High School, Independent)                                   NaN
# (Hernandez High School, Government)                                  NaN
# (Holden High School, Independent)                                    NaN
# (Huang High School, Government)                                      NaN
# (Johnson High School, Government)                                    NaN
# (Pena High School, Independent)                                      NaN
# (Rodriguez High School, Government)                                  NaN
# (Shelton High School, Independent)                                   NaN
# (Thomas High School, Independent)                                    NaN
# (Wilson High School, Independent)                                    NaN
# (Wright High School, Independent)                                    NaN
#
#                                                                                      1  \
# 0                                           Student ID         student_name gender ...
# 1                                           Student ID    student_name gender  year...
# 2                                          Student ID     student_name gender  year...
# 3                                           Student ID     student_name gender  yea...
# 4                                           Student ID       student_name gender  y...
# 5                                           Student ID       student_name gender  y...
# 6                                           Student ID       student_name gender  y...
# 7                                          Student ID     student_name gender  year...
# 8                                           Student ID     student_name gender  yea...
# 9                                           Student ID        student_name gender  ...
# 10                                          Student ID       student_name gender  y...
# 11                                         Student ID      student_name gender  yea...
# 12                                          Student ID     student_name gender  yea...
# 13                                          Student ID       student_name gender  y...
# 14                                          Student ID       student_name gender  y...
# (Bailey High School, Government)                                                   NaN
# (Cabrera High School, Independent)                                                 NaN
# (Figueroa High School, Government)                                                 NaN
# (Ford High School, Government)                                                     NaN
# (Griffin High School, Independent)                                                 NaN
# (Hernandez High School, Government)                                                NaN
# (Holden High School, Independent)                                                  NaN
# (Huang High School, Government)                                                    NaN
# (Johnson High School, Government)                                                  NaN
# (Pena High School, Independent)                                                    NaN
# (Rodriguez High School, Government)                                                NaN
# (Shelton High School, Independent)                                                 NaN
# (Thomas High School, Independent)                                                  NaN
# (Wilson High School, Independent)                                                  NaN
# (Wright High School, Independent)                                                  NaN
#
#                                      Student ID
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9                                           NaN
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# (Bailey High School, Government)         4976.0
# (Cabrera High School, Independent)       1858.0
# (Figueroa High School, Government)       2949.0
# (Ford High School, Government)           2739.0
# (Griffin High School, Independent)       1468.0
# (Hernandez High School, Government)      4635.0
# (Holden High School, Independent)         427.0
# (Huang High School, Government)          2917.0
# (Johnson High School, Government)        4761.0
# (Pena High School, Independent)           962.0
# (Rodriguez High School, Government)      3999.0
# (Shelton High School, Independent)       1761.0
# (Thomas High School, Independent)        1635.0
# (Wilson High School, Independent)        2283.0
# (Wright High School, Independent)        1800.0

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %% [markdown]
# ## Maths Scores by Year

# %% [markdown]
# * Create a table that lists the average maths score for students of each year level (9, 10, 11, 12) at each school.
#
#   * Create a pandas series for each year. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Year

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
